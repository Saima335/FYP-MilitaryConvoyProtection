# %%
from google.colab import drive
# !mkdir datasets
drive.mount('/content/datasets/drive')#/content/datasets
# Out:
# Mounted at /content/datasets/drive

# %%
# !pip install ultralytics==8.0.56
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !nvidia-smi
# Out:
# Wed Apr 12 16:09:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)

# HOME = "/content"

# %cd {HOME}
# Out:
# /content
# /content

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.56 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.2/78.2 GB disk)

# %% [markdown]
# ---

# %% [markdown]
# Training on Custom Dataset

# %%
HOME = "/content/datasets/drive/MyDrive"

# %cd {HOME}

#yolo task=detect mode=train pretrained=true model="{HOME}/runs/detect/train/weights/last.pt" data="{HOME}/visdrone.yaml" epochs=100 save=true imgsz=640

# !yolo task=detect mode=train model="{HOME}/runs/detect/train4/weights/last.pt" data="{HOME}/visdrone.yaml" resume=true epochs=100 save=true


#%cp -av {HOME}/runs/detect/val {HOME}/datasets/drive/Mydrive/val

# %%
#From Ultralytics Hub
from ultralytics import YOLO, checks, hub

hub.start('8bd86f775a47083ec21d26c39a37c452ef46bb2dc9_EiQX9Hp0O4wHnXOL1MZH')
# Out:
# Ultralytics HUB: 0.000 GB dataset, 44.1/78.2 GB free disk space
# New https://pypi.org/project/ultralytics/8.0.74 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.56 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={HOME}/visdrone.yaml

# %%
# !yolo export model=/content/datasets/drive/MyDrive/runs/detect/train2/weights/best.pt imgsz=640 format=onnx opset=12
# Out:
# 2023-04-13 03:11:48.801885: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 03:11:50.215750: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.56 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
#
# PyTorch: starting from /content/datasets/drive/MyDrive/runs/detect/train2/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (83.6 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
model = YOLO("/content/datasets/drive/MyDrive/train/train/weights/best.pt")

model.predict(
    source='/content/datasets/drive/MyDrive/train/DJI_0012.mp4',
    conf=0.25,
    save=True,
    imgsz=1280
)

# %%
from ultralytics.yolo.utils.benchmarks import benchmark

# Benchmark
benchmark(model='runs/detect/train3/weights/best.pt', imgsz=640, half=False, device=0)
# Out:
# image 1/1 /usr/local/lib/python3.9/dist-packages/ultralytics/assets/bus.jpg: 640x480 (no detections), 65.9ms
# Speed: 0.6ms preprocess, 65.9ms inference, 22.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.56 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Dataset 'coco128.yaml' images not found ⚠️, missing paths ['/content/datasets/coco128/images/train2017']
# ...
# 100%|██████████| 6.66M/6.66M [00:00<00:00, 166MB/s]
# Unzipping /content/datasets/coco128.zip to /content/datasets...
# Dataset download success ✅ (0.4s), saved to /content/datasets
#
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 47.4MB/s]
# val: Scanning /content/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<00:00, 1717.42it/s]
# val: New cache created: /content/datasets/coco128/labels/train2017.cache
# ...
